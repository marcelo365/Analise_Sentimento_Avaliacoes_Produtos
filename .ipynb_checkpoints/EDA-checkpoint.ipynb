# %%
'''
Visualizações de estatísticas de texto são técnicas simples, mas muito informativas.

Elas incluem:

análise de frequência de palavras,

análise do comprimento das frases,

análise do comprimento médio das palavras
'''

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import  Counter
from collections import defaultdict
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from nltk.corpus import stopwords
from collections import Counter

# %matplotlib inline
sns.set_style("darkgrid")

# %%
df_balanced = pd.read_excel('./df_balanced.xlsx')
df_balanced.head()
#df_balanced.info()
#df_balanced.describe()
# Out:
#   sentiments                                     cleaned_review  \
# 0   positive  sounds so good and gets very loud bluetooth co...
# 1   positive  hi and use this for gaming and distance learni...
# 2    neutral  this mouse quit working after weeks poor quali...
# 3   negative  the scroll wheel broke after months have food ...
# 4    neutral  it stopped working after months can even retur...
#
#    cleaned_review_length  review_score  sentiments_final
# 0                     30             3                 2
# 1                     55             5                 2
# 2                      9             5                 1
# 3                     17             5                 0
# 4                      9             1                 1

# %%
stop = set(stopwords.words('english'))
stop.discard('not')

# Histograma do número de palavras por review
plt.figure(figsize=(10,6))
df_balanced['cleaned_review'].str.split()\
    .map(lambda x: len(x))\
    .hist(bins=20, color='lightgreen', edgecolor='black')

plt.title('Distribuição do número de palavras por review')
plt.xlabel('Número de palavras')
plt.ylabel('Quantidade de reviews')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

def plot_top_non_stopwords_barchart(text_series, top_n=40):
    # Divide cada review em palavras
    words_list = text_series.str.split().values.tolist()
    
    # Cria um corpus plano
    corpus = [word.lower() for review in words_list for word in review]
    
    # Conta frequência das palavras
    counter = Counter(corpus)
    
    # Filtra as stopwords e pega as top_n palavras
    most = [(word, count) for word, count in counter.most_common() if word not in stop][:top_n]
    
    # Separa palavras e contagens para plotar
    x, y = zip(*most)
    
    # Plota com Seaborn
    plt.figure(figsize=(10, 12))
    sns.barplot(x=y, y=x, palette="viridis")
    plt.title(f'Top {top_n} palavras (sem stopwords)')
    plt.xlabel('Frequência')
    plt.ylabel('Palavra')
    plt.show()

# Chama a função com o nosso df
plot_top_non_stopwords_barchart(df_balanced['cleaned_review'])
# Out:
# C:\Users\Ernesto\AppData\Local\Temp\ipykernel_13992\1576364082.py:34: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=y, y=x, palette="viridis")

# %%
sns.countplot(x='sentiments_final', data=df_balanced)
plt.title('Distribuição das Classes de Sentimento')
plt.xlabel('Sentimento')
plt.ylabel('Contagem')
plt.show()

#0 negativa, 1 neuto, 2 positivo

# %%
sns.histplot(df_balanced['cleaned_review_length'], bins=50, kde=True)
plt.title('Distribuição do Comprimento dos Reviews')
plt.xlabel('Número de Palavras')
plt.show()

# %%
sns.boxplot(x='sentiments_final', y='cleaned_review_length', data=df_balanced)
plt.title('Comprimento do Texto por Sentimento')
plt.xlabel('Sentimento')
plt.ylabel('Número de Palavras')
plt.show()

# %%
# Mantemos o set de stopwords
stop = set(stopwords.words('english'))
stop.discard('not')  # mantém 'not'

# Cria o corpus
corpus = [word.lower() for review in df_balanced['cleaned_review'].str.split().values.tolist() for word in review]

# Conta todas as palavras
counter = Counter(corpus)
most = counter.most_common()

# Filtra as top 40 palavras que não são stopwords
x, y = [], []
for word, count in most[:40]:
    if word not in stop:
        x.append(word)
        y.append(count)

# Plota
plt.figure(figsize=(8,6))
sns.barplot(
    x=y,
    y=x,
    hue=x,
    palette="viridis",
    legend=False
)

plt.title('Top 40 palavras mais frequentes (excluindo stopwords)')
plt.xlabel('Frequência')
plt.ylabel('Palavra')
plt.show()

# %%
stop_words = set(stopwords.words('english'))
stop_words.discard('not')

for label in df_balanced['sentiments_final'].unique():
    subset = df_balanced[df_balanced['sentiments_final'] == label]

    words = " ".join(subset['cleaned_review']).lower().split()
    words = [w for w in words if w not in stop_words and len(w) > 2]

    common_words = Counter(words).most_common(15)

    print(f"Sentimento {label}:")
    print([word for word, _ in common_words])
    print("-" * 30)
# Out:
# Sentimento 2:
# ['great', 'mouse', 'sound', 'use', 'not', 'good', 'love', 'one', 'like', 'quality', 'charge', 'works', 'keyboard', 'work', 'battery']
# ------------------------------
# Sentimento 1:
# ['not', 'mouse', 'work', 'use', 'working', 'one', 'stopped', 'like', 'charge', 'good', 'months', 'product', 'would', 'sound', 'usb']
# ------------------------------
# Sentimento 0:
# ['not', 'mouse', 'working', 'use', 'one', 'work', 'charge', 'would', 'stopped', 'keyboard', 'bought', 'even', 'broke', 'time', 'months']
# ------------------------------

# %%
# Mantemos o set de stopwords, mas não removemos "not"
stop_words = set(stopwords.words('english'))
stop_words.discard('not')

# Função para plotar top ngrams
def plot_top_ngrams(text_series, ngram_range=(2,2), top_n=15):
    vectorizer = CountVectorizer(stop_words=list(stop_words), ngram_range=ngram_range, min_df=1)
    X = vectorizer.fit_transform(text_series)
    
    # Frequência de cada ngram
    sum_words = X.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
    words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)[:top_n]
    
    x, y = zip(*words_freq)
    
    plt.figure(figsize=(5,5))
    sns.barplot(x=y, y=x, palette='viridis',hue=x)
    
    plt.title(f'Top {top_n} ngrams')
    plt.xlabel('Frequência')
    plt.ylabel('Ngram')
    plt.show()

# Loop por sentimento
for label in df_balanced['sentiments_final'].unique():
    subset = df_balanced[df_balanced['sentiments_final'] == label]
    print(f"Sentimento {label}:")
    plot_top_ngrams(subset['cleaned_review'], ngram_range=(2,2), top_n=15)
    print("-"*30)
# Out:
# Sentimento 2:
# ------------------------------
# Sentimento 1:
# ------------------------------
# Sentimento 0:
# ------------------------------

# %%
stop_words = set(stopwords.words('english'))
stop_words.discard('not')

def plot_top_tfidf(text_series, top_n=15, ngram_range=(1,1)):
    """
    Plota os top_n termos mais relevantes segundo TF-IDF
    """
    vectorizer = TfidfVectorizer(stop_words=list(stop_words), ngram_range=ngram_range)
    X = vectorizer.fit_transform(text_series)
    
    # Calcula a média de TF-IDF de cada termo
    tfidf_mean = X.mean(axis=0).A1  # .A1 transforma em array 1D
    terms = vectorizer.get_feature_names_out()
    
    # Junta termos e seus scores
    tfidf_scores = list(zip(terms, tfidf_mean))
    
    # Ordena pelo score
    tfidf_scores = sorted(tfidf_scores, key=lambda x: x[1], reverse=True)[:top_n]
    
    x, y = zip(*tfidf_scores)
    
    plt.figure(figsize=(10,6))
    sns.barplot(x=y, y=x, palette='magma',hue=x)
    plt.title(f'Top {top_n} termos segundo TF-IDF')
    plt.xlabel('TF-IDF médio')
    plt.ylabel('Termo')
    plt.show()

# Exemplo: por sentimento
for label in df_balanced['sentiments_final'].unique():
    subset = df_balanced[df_balanced['sentiments_final'] == label]
    print(f"Sentimento {label}:")
    plot_top_tfidf(subset['cleaned_review'], top_n=15, ngram_range=(1,1))
    print("-"*30)
# Out:
# Sentimento 2:
# ------------------------------
# Sentimento 1:
# ------------------------------
# Sentimento 0:
# ------------------------------

# %%
# Mantemos o set de stopwords
stop = set(stopwords.words('english'))
stop.discard('not')  # mantém 'not'

# Cria o corpus
corpus = []
new = df_balanced['cleaned_review'].str.split()
new = new.values.tolist()
corpus = [word.lower() for review in new for word in review]

# Conta a frequência das stopwords
dic = defaultdict(int)
for word in corpus:
    if word in stop:
        dic[word] += 1

# Ordena as mais comuns
sorted_stopwords = sorted(dic.items(), key=lambda x: x[1], reverse=True)
words, counts = zip(*sorted_stopwords[:20])  # pega top 20 stopwords

# Plota
plt.figure(figsize=(10,8))
sns.barplot(x=counts, y=words, palette='magma',hue=words)
plt.title('Top 20 Stopwords mais frequentes')
plt.xlabel('Frequência')
plt.ylabel('Stopword')
plt.show()

# %%
# TF-IDF
vectorizer = TfidfVectorizer(stop_words=list(stop_words))
X = vectorizer.fit_transform(df_balanced['cleaned_review'])

# PCA 2D
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X.toarray())

# Plotando
plt.figure(figsize=(10,6))
for label in df_balanced['sentiments_final'].unique():
    subset_idx = df_balanced['sentiments_final'] == label
    plt.scatter(X_pca[subset_idx,0], X_pca[subset_idx,1], label=f'Sentimento {label}', alpha=0.6)
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.title('Visualização 2D das classes (TF-IDF + PCA)')
plt.legend()
plt.show()

# %%
for label in df_balanced['sentiments_final'].unique():
    text = " ".join(df_balanced[df_balanced['sentiments_final']==label]['cleaned_review'])
    wc = WordCloud(width=800, height=400, background_color='white').generate(text)
    plt.figure(figsize=(10,4))
    plt.imshow(wc)
    plt.axis('off')
    plt.title(f'WordCloud - Sentimento {label}')
    plt.show()

# %%
df_balanced[['cleaned_review_length', 'review_score', 'sentiments_final']].corr()
sns.heatmap(df_balanced[['cleaned_review_length', 'review_score', 'sentiments_final']].corr(), annot=True, cmap='coolwarm')
plt.title('Matriz de Correlação')
plt.show()
